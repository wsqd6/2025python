# %% [markdown]
# #kaggle上运行,需gpu

# %%
# !ls /
# Out:
# bin
# cmd
# dev
# etc
# Git-2.52.0-64-bit.exe
# git-bash.exe
# git-cmd.exe
# LICENSE.txt
# mingw64
# proc
# ReleaseNotes.html
# tmp
# unins000.dat
# unins000.exe
# unins000.msg
# usr

# %%
# !pwd
# Out:
# /d/PyCharm1/2025python/deep_learning

# %%
# !nvcc -V
# Out:
# 'nvcc' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���

# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���

# %%
#验证cuda是否ok
import torch
print(torch.backends.cudnn.version())
print(torch.cuda.is_available())
print(torch.backends.cudnn.enabled)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 #验证cuda是否ok
# ----> 2 import torch
#       3 print(torch.backends.cudnn.version())
#       4 print(torch.cuda.is_available())
#
# ModuleNotFoundError: No module named 'torch'

# %%
torch.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 torch.__version__
#
# NameError: name 'torch' is not defined

# %%
#numpy最新版本可能与torch有冲突,建议1.26.4,但是3.12装不上numpy1.26.4
import numpy
print(numpy.__version__)
# Out:
# 2.4.1
