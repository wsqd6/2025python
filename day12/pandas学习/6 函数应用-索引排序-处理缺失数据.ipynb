# %% [markdown]
# # 6 Pandas的函数应用

# %%
import pandas as pd
import numpy as np
# Numpy ufunc 函数，randn跟的是维数
df = pd.DataFrame(np.random.randn(5,4) - 1)
print(df)

print(np.abs(df)) #绝对值
# Out:
#           0         1         2         3
# 0 -0.701971 -2.141038 -1.082675 -2.140841
# 1 -2.163613 -1.395365 -2.006154 -0.538319
# 2  0.186086 -1.276898  0.647076  0.088668
# 3 -2.580657  0.325606 -0.415004 -1.244450
# 4 -0.988031  0.192831 -0.407368 -0.485144
#           0         1         2         3
# 0  0.701971  2.141038  1.082675  2.140841
# 1  2.163613  1.395365  2.006154  0.538319
# 2  0.186086  1.276898  0.647076  0.088668
# 3  2.580657  0.325606  0.415004  1.244450
# 4  0.988031  0.192831  0.407368  0.485144

# %%
#apply默认作用在列上,x是每一列,因为axis=0
print(df.apply(lambda x : x.max()))
# Out:
# 0    0.186086
# 1    0.325606
# 2    0.647076
# 3    0.088668
# dtype: float64

# %%
#apply作用在行上
print(df.apply(lambda x : x.max(), axis=1))
# Out:
# 0   -0.701971
# 1   -0.538319
# 2    0.647076
# 3    0.325606
# 4    0.192831
# dtype: float64

# %%
# 使用applymap应用到每个数据
print(df.map(lambda x : '%.2f' % x))
df.dtypes
# Out:
#        0      1      2      3
# 0  -0.70  -2.14  -1.08  -2.14
# 1  -2.16  -1.40  -2.01  -0.54
# 2   0.19  -1.28   0.65   0.09
# 3  -2.58   0.33  -0.42  -1.24
# 4  -0.99   0.19  -0.41  -0.49
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
type('%.2f' % 1.3456)
# Out:
# str

# %% [markdown]
# ## 6.4 索引排序（不重要）

# %%
# Series
print(np.random.randint(5, size=5))
print('-'*50)
s4 = pd.Series(range(10, 15), index = np.random.randint(5, size=5)) #索引随机生成
print(s4)
print('-'*50)
# 索引排序,sort_index返回一个新的排好索引的series
print(s4.sort_index())
print(s4)
# s4.loc[0:3]  loc索引值不唯一时直接报错
print(s4.iloc[0:3])
s4[0:3]  #默认用的位置索引
# Out:
# [4 4 1 2 1]
# --------------------------------------------------
# 3    10
# 1    11
# 1    12
# 1    13
# 2    14
# dtype: int64
# --------------------------------------------------
# 1    11
# 1    12
# 1    13
# 2    14
# 3    10
# dtype: int64
# 3    10
# 1    11
# 1    12
# 1    13
# 2    14
# dtype: int64
# 3    10
# 1    11
# 1    12
# dtype: int64
# 3    10
# 1    11
# 1    12
# dtype: int64

# %%
# s4.loc[1:2] #loc索引值唯一时可以切片

# %%
# DataFrame
df4 = pd.DataFrame(np.random.randn(5, 5),
                   index=np.random.randint(5, size=5),
                   columns=np.random.randint(5, size=5))
print(df4)
#轴零是行索引排序
df4_isort = df4.sort_index(axis=0, ascending=False)
print(df4_isort)
# Out:
#           1         0         3         4         4
# 4 -0.088891 -0.768851  0.994454 -1.007004 -0.046068
# 1  0.961481  1.648658 -0.620263 -0.614667 -0.687817
# 0  1.053610  0.835965 -0.303332 -0.914418 -1.072485
# 4  0.598910 -1.518171  2.325199 -0.209359  0.094464
# 1  0.474102  0.587157  0.805704  0.968778 -0.510804
#           1         0         3         4         4
# 4 -0.088891 -0.768851  0.994454 -1.007004 -0.046068
# 4  0.598910 -1.518171  2.325199 -0.209359  0.094464
# 1  0.961481  1.648658 -0.620263 -0.614667 -0.687817
# 1  0.474102  0.587157  0.805704  0.968778 -0.510804
# 0  1.053610  0.835965 -0.303332 -0.914418 -1.072485

# %%
#轴1是列索引排序
df4_isort = df4.sort_index(axis=1, ascending=True)
print(df4_isort)
# Out:
#           0         1         3         4         4
# 4 -0.768851 -0.088891  0.994454 -1.007004 -0.046068
# 1  1.648658  0.961481 -0.620263 -0.614667 -0.687817
# 0  0.835965  1.053610 -0.303332 -0.914418 -1.072485
# 4 -1.518171  0.598910  2.325199 -0.209359  0.094464
# 1  0.587157  0.474102  0.805704  0.968778 -0.510804

# %% [markdown]
# # 6.5 按值排序（机器学习，深度学习不重要，数据分析才需要）

# %%
# 按值排序,by后是column的值
import random
l=[random.randint(0,100) for i in range(24)] #生成24个随机数
df4 = pd.DataFrame(np.array(l).reshape(6,4)) #生成6行4列的dataframe
# print(df4) #查看数据,ndarray
# print('-'*50)
print(df4)
print('-'*50)
#按轴零排序，by后是列名,交换的是行
df4_vsort = df4.sort_values(by=3,axis=0, ascending=False) #寻找的是columns里的3,重要
print(df4_vsort)
# Out:
#     0   1   2   3
# 0  90  35  71  72
# 1  67  90  25  93
# 2  88  79   2  68
# 3  39  78  79  80
# 4  24  56  80  38
# 5   1   0  39  59
# --------------------------------------------------
#     0   1   2   3
# 1  67  90  25  93
# 3  39  78  79  80
# 0  90  35  71  72
# 2  88  79   2  68
# 5   1   0  39  59
# 4  24  56  80  38

# %%
#按轴1排序，by后行索引名，交换的是列
df4_vsort = df4.sort_values(by=3,axis=1, ascending=False) #寻找的是index里的3
print(df4_vsort)
# Out:
#     3   2   1   0
# 0  72  71  35  90
# 1  93  25  90  67
# 2  68   2  79  88
# 3  80  79  78  39
# 4  38  80  56  24
# 5  59  39   0   1

# %% [markdown]
# # 6.6 处理缺失数据（重要）

# %%
df_data = pd.DataFrame([np.random.randn(3), [1., 2., np.nan],
                       [np.nan, 4., np.nan], [1., 2., 3.]])
print(df_data.head())
# Out:
#           0         1         2
# 0 -0.617616  0.856628 -0.916661
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
df_data.iloc[2,0]
# Out:
# nan

# %%
#isnull来判断是否有空的数据
print(df_data.isnull())
# Out:
#        0      1      2
# 0  False  False  False
# 1  False  False   True
# 2   True  False   True
# 3  False  False  False

# %%
#帮我计算df_data缺失率
print(df_data.isnull().sum()/len(df_data))
# Out:
# 0    0.25
# 1    0.00
# 2    0.50
# dtype: float64

# %% [markdown]
# ## 删除缺失数据

# %%
#默认一个样本，任何一个特征缺失，就删除
#inplace True是修改的是原有的df
#subset=[0]是指按第一列来删除,第一列有空值就删除对应的行
print(df_data.dropna(subset=[0]))
# df_data
# Out:
#           0         1         2
# 0 -0.617616  0.856628 -0.916661
# 1  1.000000  2.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
df_data
# Out:
#           0         1         2
# 0 -0.617616  0.856628 -0.916661
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
#用的不多，用在某个特征缺失太多时，才会进行删除
print(df_data.dropna(axis=1))  #某列由nan就删除该列
# Out:
#           1
# 0  0.856628
# 1  2.000000
# 2  4.000000
# 3  2.000000

# %%
df_data
# Out:
#           0         1         2
# 0 -0.617616  0.856628 -0.916661
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %% [markdown]
# ## 填充缺失数据

# %%
#均值，中位数，众数填充

# %%
#给零列的空值填为-100，按特征（按列）去填充
print(df_data.iloc[:,0].fillna(-100.))
df_data
# Out:
# 0     -0.617616
# 1      1.000000
# 2   -100.000000
# 3      1.000000
# Name: 0, dtype: float64
#           0         1         2
# 0 -0.617616  0.856628 -0.916661
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
#依次拿到每一列
for i in df_data.columns:
    print(df_data.loc[:,i])
# Out:
# 0   -0.617616
# 1    1.000000
# 2         NaN
# 3    1.000000
# Name: 0, dtype: float64
# 0    0.856628
# 1    2.000000
# 2    4.000000
# 3    2.000000
# Name: 1, dtype: float64
# 0   -0.916661
# 1         NaN
# 2         NaN
# 3    3.000000
# Name: 2, dtype: float64

# %%
df_data.iloc[:,0].fillna(-100.,inplace=True) #inplace=True后面会被删除
# Out:
# C:\Users\邓威\AppData\Local\Temp\ipykernel_28168\2218614896.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_data.iloc[:,0].fillna(-100.,inplace=True) #inplace=True后面会被删除

# %%
df_data.iloc[:,2]=df_data.iloc[:,2].fillna(df_data.iloc[:,2].mean()) #用均值填充空值

# %%
df_data
# Out:
#             0         1         2
# 0   -0.617616  0.856628 -0.916661
# 1    1.000000  2.000000  1.041669
# 2 -100.000000  4.000000  1.041669
# 3    1.000000  2.000000  3.000000
