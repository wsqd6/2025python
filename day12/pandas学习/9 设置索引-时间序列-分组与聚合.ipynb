# %% [markdown]
# # 9 Pandas分组与聚合

# %% [markdown]
# # 设置索引

# %%
import pandas as pd
import numpy as np

# %%
#索引中单项不可变，但是整体可以换掉
a = pd.DataFrame({'a': range(7),'b': range(7, 0, -1),
                  'c': ['one','one','one','two','two','two', 'two'],
                  'd': list("hjklmno")})
a
# Out:
#    a  b    c  d
# 0  0  7  one  h
# 1  1  6  one  j
# 2  2  5  one  k
# 3  3  4  two  l
# 4  4  3  two  m
# 5  5  2  two  n
# 6  6  1  two  o

# %%
c=a.copy()
a.index=list('abcdefg')  #a的索引变了，a.index更换索引
print(c)
# a.columns=list('ABCD')  #a的列名变了，a.columns更换列名
print('-'*50)
print(a)
# Out:
#    a  b    c  d
# 0  0  7  one  h
# 1  1  6  one  j
# 2  2  5  one  k
# 3  3  4  two  l
# 4  4  3  two  m
# 5  5  2  two  n
# 6  6  1  two  o
# --------------------------------------------------
#    a  b    c  d
# a  0  7  one  h
# b  1  6  one  j
# c  2  5  one  k
# d  3  4  two  l
# e  4  3  two  m
# f  5  2  two  n
# g  6  1  two  o

# %%
c.values.shape
# Out:
# (7, 4)

# %%
#让某些列变为索引，让c列，d列数据变为索引
print(a)
print('-'*50)
a.set_index(['c'],inplace=True)#a没变，返回修改后的df
a
# Out:
#    a  b    c  d
# a  0  7  one  h
# b  1  6  one  j
# c  2  5  one  k
# d  3  4  two  l
# e  4  3  two  m
# f  5  2  two  n
# g  6  1  two  o
# --------------------------------------------------
#      a  b  d
# c
# one  0  7  h
# one  1  6  j
# one  2  5  k
# two  3  4  l
# two  4  3  m
# two  5  2  n
# two  6  1  o

# %%
a.columns
# Out:
# Index(['a', 'b', 'd'], dtype='object')

# %%
a.index
# Out:
# Index(['one', 'one', 'one', 'two', 'two', 'two', 'two'], dtype='object', name='c')

# %% [markdown]
# ### 时间序列

# %%
pd.date_range(start="20190101", end="20190201")
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12',
#                '2019-01-13', '2019-01-14', '2019-01-15', '2019-01-16',
#                '2019-01-17', '2019-01-18', '2019-01-19', '2019-01-20',
#                '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24',
#                '2019-01-25', '2019-01-26', '2019-01-27', '2019-01-28',
#                '2019-01-29', '2019-01-30', '2019-01-31', '2019-02-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start="20250107",periods=10,freq='B')
# Out:
# DatetimeIndex(['2025-01-07', '2025-01-08', '2025-01-09', '2025-01-10',
#                '2025-01-13', '2025-01-14', '2025-01-15', '2025-01-16',
#                '2025-01-17', '2025-01-20'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start="20190101",periods=10,freq='ME')
# Out:
# DatetimeIndex(['2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
#                '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#                '2019-09-30', '2019-10-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
pd.date_range(start="20190101",periods=10,freq='MS')
# Out:
# DatetimeIndex(['2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
pd.date_range(start="20230710",periods=10,freq='W')  #拿每周的周日生成
# Out:
# DatetimeIndex(['2023-07-16', '2023-07-23', '2023-07-30', '2023-08-06',
#                '2023-08-13', '2023-08-20', '2023-08-27', '2023-09-03',
#                '2023-09-10', '2023-09-17'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
s = pd.Series(['3/11/2000', '3/12/2000', '3/13/2000'] * 5)
s
# Out:
# 0     3/11/2000
# 1     3/12/2000
# 2     3/13/2000
# 3     3/11/2000
# 4     3/12/2000
# 5     3/13/2000
# 6     3/11/2000
# 7     3/12/2000
# 8     3/13/2000
# 9     3/11/2000
# 10    3/12/2000
# 11    3/13/2000
# 12    3/11/2000
# 13    3/12/2000
# 14    3/13/2000
# dtype: object

# %%
#timeit可以统计执行耗时，to_datetime把字符串转为时间格式
pd.to_datetime(s)
# Out:
# 0    2000-03-11
# 1    2000-03-12
# 2    2000-03-13
# 3    2000-03-11
# 4    2000-03-12
# 5    2000-03-13
# 6    2000-03-11
# 7    2000-03-12
# 8    2000-03-13
# 9    2000-03-11
# 10   2000-03-12
# 11   2000-03-13
# 12   2000-03-11
# 13   2000-03-12
# 14   2000-03-13
# dtype: datetime64[ns]

# %%
#实战美国911数据
from matplotlib import pyplot as plt

# 把时间字符串转为时间类型设置为索引
df = pd.read_csv("./911.csv")
df["timeStamp"] = pd.to_datetime(df["timeStamp"])

# 添加列，表示分类
temp_list = df["title"].str.split(": ").tolist() #二维列表
cate_list = [i[0] for i in temp_list] #i[0]就是EMS  Fire  Traffic
# print(cate_list)
# print(np.array(cate_list).reshape((df.shape[0], 1)))
 #添加一列
df["cate"] = pd.DataFrame(np.array(cate_list).reshape((df.shape[0], 1)))

df.set_index("timeStamp", inplace=True) #设置索引，时间戳，inplace=True表示在原df上修改

df.head(10)
# Out:
#                            lat        lng  \
# timeStamp
# 2015-12-10 17:10:52  40.297876 -75.581294
# 2015-12-10 17:29:21  40.258061 -75.264680
# 2015-12-10 14:39:21  40.121182 -75.351975
# 2015-12-10 16:47:36  40.116153 -75.343513
# 2015-12-10 16:56:52  40.251492 -75.603350
# 2015-12-10 15:39:04  40.253473 -75.283245
# 2015-12-10 16:46:48  40.182111 -75.127795
# 2015-12-10 16:17:05  40.217286 -75.405182
# 2015-12-10 16:51:42  40.289027 -75.399590
# 2015-12-10 17:35:41  40.102398 -75.291458
#
#                                                                   desc  \
# timeStamp
# 2015-12-10 17:10:52  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 2015-12-10 17:29:21  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2015-12-10 14:39:21  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 2015-12-10 16:47:36  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 2015-12-10 16:56:52  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# 2015-12-10 15:39:04  CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...
# 2015-12-10 16:46:48  LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...
# 2015-12-10 16:17:05  COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...
# 2015-12-10 16:51:42  MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...
# 2015-12-10 17:35:41  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...
#
#                          zip                        title                twp  \
# timeStamp
# 2015-12-10 17:10:52  19525.0       EMS: BACK PAINS/INJURY        NEW HANOVER
# 2015-12-10 17:29:21  19446.0      EMS: DIABETIC EMERGENCY  HATFIELD TOWNSHIP
# 2015-12-10 14:39:21  19401.0          Fire: GAS-ODOR/LEAK         NORRISTOWN
# 2015-12-10 16:47:36  19401.0       EMS: CARDIAC EMERGENCY         NORRISTOWN
# 2015-12-10 16:56:52      NaN               EMS: DIZZINESS   LOWER POTTSGROVE
# 2015-12-10 15:39:04  19446.0             EMS: HEAD INJURY           LANSDALE
# 2015-12-10 16:46:48  19044.0         EMS: NAUSEA/VOMITING            HORSHAM
# 2015-12-10 16:17:05  19426.0   EMS: RESPIRATORY EMERGENCY           SKIPPACK
# 2015-12-10 16:51:42  19438.0        EMS: SYNCOPAL EPISODE      LOWER SALFORD
# 2015-12-10 17:35:41  19462.0  Traffic: VEHICLE ACCIDENT -           PLYMOUTH
#
#                                                          addr  e     cate
# timeStamp
# 2015-12-10 17:10:52                    REINDEER CT & DEAD END  1      EMS
# 2015-12-10 17:29:21                BRIAR PATH & WHITEMARSH LN  1      EMS
# 2015-12-10 14:39:21                                  HAWS AVE  1     Fire
# 2015-12-10 16:47:36                        AIRY ST & SWEDE ST  1      EMS
# 2015-12-10 16:56:52                  CHERRYWOOD CT & DEAD END  1      EMS
# 2015-12-10 15:39:04                     CANNON AVE & W 9TH ST  1      EMS
# 2015-12-10 16:46:48                  LAUREL AVE & OAKDALE AVE  1      EMS
# 2015-12-10 16:17:05              COLLEGEVILLE RD & LYWISKI RD  1      EMS
# 2015-12-10 16:51:42             MAIN ST & OLD SUMNEYTOWN PIKE  1      EMS
# 2015-12-10 17:35:41  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD  1  Traffic

# %%
plt.figure(figsize=(20, 8), dpi=80)

# 分组,一图多线
#resample降采样，按月统计,索引必须是时间类型，类似groupby
for group_name, group_data in df.groupby(by="cate"):
    # 对不同的分类都进行绘图
    count_by_month = group_data.resample("M").count()["title"]  #降采样
    print(count_by_month)
    # 画图
    _x = count_by_month.index
    print(_x)
    _y = count_by_month.values #values是对应事故发生次数

    _x = [i.strftime("%Y%m%d") for i in _x]  #变年月日格式

    plt.plot(_x, _y, label=group_name)

plt.xticks(range(len(_x)), _x, rotation=45)
plt.legend(loc="best")
plt.show()
# Out:
# C:\Users\邓威\AppData\Local\Temp\ipykernel_24912\3777774160.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   count_by_month = group_data.resample("M").count()["title"]  #降采样
# timeStamp
# 2015-12-31    3898
# 2016-01-31    6063
# 2016-02-29    5413
# 2016-03-31    5832
# 2016-04-30    5684
# 2016-05-31    5730
# 2016-06-30    5720
# 2016-07-31    6029
# 2016-08-31    6005
# 2016-09-30    5750
# 2016-10-31    6039
# 2016-11-30    5838
# 2016-12-31    6024
# 2017-01-31    6082
# 2017-02-28    5417
# 2017-03-31    5913
# 2017-04-30    5780
# 2017-05-31    5948
# 2017-06-30    6030
# 2017-07-31    5974
# 2017-08-31    5882
# 2017-09-30    3789
# Freq: ME, Name: title, dtype: int64
# DatetimeIndex(['2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31',
#                '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31',
#                '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30',
#                '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31',
#                '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31',
#                '2017-08-31', '2017-09-30'],
#               dtype='datetime64[ns]', name='timeStamp', freq='ME')
# timeStamp
# 2015-12-31    1095
# 2016-01-31    1904
# 2016-02-29    1868
# 2016-03-31    1589
# 2016-04-30    1717
# 2016-05-31    1573
# 2016-06-30    1787
# 2016-07-31    1898
# 2016-08-31    1907
# 2016-09-30    1793
# 2016-10-31    1930
# 2016-11-30    1765
# 2016-12-31    1846
# 2017-01-31    1658
# 2017-02-28    1462
# 2017-03-31    1634
# 2017-04-30    1614
# 2017-05-31    1670
# 2017-06-30    1986
# 2017-07-31    1754
# 2017-08-31    1862
# 2017-09-30    1120
# Freq: ME, Name: title, dtype: int64
# DatetimeIndex(['2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31',
#                '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31',
#                '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30',
#                '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31',
#                '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31',
#                '2017-08-31', '2017-09-30'],
#               dtype='datetime64[ns]', name='timeStamp', freq='ME')
# timeStamp
# 2015-12-31    2923
# 2016-01-31    5129
# 2016-02-29    4115
# 2016-03-31    3638
# 2016-04-30    3886
# 2016-05-31    4071
# 2016-06-30    4225
# 2016-07-31    4161
# 2016-08-31    3992
# 2016-09-30    4126
# 2016-10-31    4533
# 2016-11-30    4488
# 2016-12-31    4292
# 2017-01-31    3865
# 2017-02-28    3388
# 2017-03-31    4137
# 2017-04-30    3662
# 2017-05-31    4101
# 2017-06-30    4317
# 2017-07-31    4040
# 2017-08-31    4009
# 2017-09-30    2367
# Freq: ME, Name: title, dtype: int64
# DatetimeIndex(['2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31',
#                '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31',
#                '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30',
#                '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31',
#                '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31',
#                '2017-08-31', '2017-09-30'],
#               dtype='datetime64[ns]', name='timeStamp', freq='ME')

# %% [markdown]
# ### 分组运算

# %%
import pandas as pd
import numpy as np

# 1. 生成测试数据
dict_obj = {
    'key1': ['a', 'b', 'a', 'b', 'a', 'b', 'a', 'a'],
    'key2': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
    'data1': np.random.randint(1, 10, 8),
    'data2': np.random.randint(1, 10, 8)
}
df_obj = pd.DataFrame(dict_obj)

# 2. 打印原始数据
print("原始数据：")
print(df_obj)
print('-' * 80)

# 3. 按key1分组，仅对数值列（data1、data2）计算均值，并添加前缀
# 筛选数值列避免字符串列求均值报错
numeric_cols = df_obj.select_dtypes(include=[np.number]).columns
k1_mean = df_obj.groupby('key1')[numeric_cols].mean().add_prefix('mean_')

# 4. 打印分组均值结果
print("按key1分组后的均值（带前缀）：")
print(k1_mean)
print('-' * 80)

# 5. 将分组统计结果合并回原始表格（附加到原始数据中）
df_merged = df_obj.merge(k1_mean, on='key1', how='left')

# 6. 打印合并后的最终数据
print("合并分组统计结果后的完整表格：")
print(df_merged)
# Out:
# 原始数据：
#   key1   key2  data1  data2
# 0    a    one      4      4
# 1    b    one      4      3
# 2    a    two      7      3
# 3    b  three      2      8
# 4    a    two      3      6
# 5    b    two      9      8
# 6    a    one      4      3
# 7    a  three      1      3
# --------------------------------------------------------------------------------
# 按key1分组后的均值（带前缀）：
#       mean_data1  mean_data2
# key1
# a            3.8    3.800000
# b            5.0    6.333333
# --------------------------------------------------------------------------------
# 合并分组统计结果后的完整表格：
#   key1   key2  data1  data2  mean_data1  mean_data2
# 0    a    one      4      4         3.8    3.800000
# 1    b    one      4      3         5.0    6.333333
# 2    a    two      7      3         3.8    3.800000
# 3    b  three      2      8         5.0    6.333333
# 4    a    two      3      6         3.8    3.800000
# 5    b    two      9      8         5.0    6.333333
# 6    a    one      4      3         3.8    3.800000
# 7    a  three      1      3         3.8    3.800000

# %%
# 方法2，使用transform，分组后计算结果和原本的df保持一致
k1_sum_tf = df_obj.groupby('key1').transform(np.mean).add_prefix('mean_')
k1_sum_tf
# df_obj[k1_sum_tf.columns] = k1_sum_tf
# print(df_obj)

# %%
df_obj.groupby('key1').mean()

# %%
import pandas as pd 
import numpy as np
# 1. 生成测试数据
dict_obj = { 'key1': ['a', 'b', 'a', 'b', 'a', 'b', 'a', 'a'], 
             'key2': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],'data1': np.random.randint(1, 10, 8), 
             'data2': np.random.randint(1, 10, 8) } 
df_obj = pd.DataFrame(dict_obj)
# 2. 打印原始数据
print("原始数据：") 
print(df_obj) 
print('-' * 80)
# 3. 按key1分组，仅对数值列（data1、data2）计算均值，并添加前缀
# 筛选数值列避免字符串列求均值报错
numeric_cols = df_obj.select_dtypes(include=[np.number]).columns 
k1_mean = df_obj.groupby('key1')[numeric_cols].mean().add_prefix('mean_')
# 4. 打印分组均值结果
print("按key1分组后的均值（带前缀）：") 
print(k1_mean) 
print('-' * 80)
# 5. 将分组统计结果合并回原始表格（附加到原始数据中）
df_merged = df_obj.merge(k1_mean, on='key1', how='left')
# 6. 打印合并后的最终数据
print("合并分组统计结果后的完整表格：") 
print(df_merged)
# Out:
# 原始数据：
#   key1   key2  data1  data2
# 0    a    one      3      7
# 1    b    one      3      3
# 2    a    two      3      5
# 3    b  three      9      7
# 4    a    two      2      1
# 5    b    two      5      4
# 6    a    one      8      4
# 7    a  three      7      6
# --------------------------------------------------------------------------------
# 按key1分组后的均值（带前缀）：
#       mean_data1  mean_data2
# key1
# a       4.600000    4.600000
# b       5.666667    4.666667
# --------------------------------------------------------------------------------
# 合并分组统计结果后的完整表格：
#   key1   key2  data1  data2  mean_data1  mean_data2
# 0    a    one      3      7    4.600000    4.600000
# 1    b    one      3      3    5.666667    4.666667
# 2    a    two      3      5    4.600000    4.600000
# 3    b  three      9      7    5.666667    4.666667
# 4    a    two      2      1    4.600000    4.600000
# 5    b    two      5      4    5.666667    4.666667
# 6    a    one      8      4    4.600000    4.600000
# 7    a  three      7      6    4.600000    4.600000

# %%
df_obj

# %%
del df_obj['key2']

# %%
df_obj.groupby('key1').transform(np.mean)

# %%
#实现a组和b组，谁比平均分高，谁比平均分低
def diff_mean(s):
    """
        返回数据与均值的差值，s传入的是某一个分组
    """
    return s - s.mean()

print(df_obj.groupby('key1').transform(diff_mean))
